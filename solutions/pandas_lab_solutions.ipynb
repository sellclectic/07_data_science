# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a data set which contains information World cup matches. Let's use the pandas commands learned in the previous lecture to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand and explain some key Pandas methods
# * Access DataFrame data by using the label
# * Perform boolean indexing on both Series and DataFrames
# * Use simple selectors for series
# * Set new Series and DataFrame inputs

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `WorldCupMatches.csv` as a dataframe in Pandas

# %%
# !ls
# Out:
# CONTRIBUTING.md     README.md           causes_of_death.tsv
# LICENSE.md          WorldCupMatches.csv index.ipynb

# %%
import pandas as pd


cup_df = pd.read_csv('WorldCupMatches.csv')
cup_df.head(2)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
#
#                   Referee               Assistant 1            Assistant 2  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)    REGO Gilberto (BRA)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)  WARNKEN Alberto (CHI)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 0      201     1096                FRA                MEX
# 1      201     1090                USA                BEL

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the data set.

# %%
cup_df.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
cup_df.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# Get a concise summary of your data using `.info()`

# %%
cup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
cup_df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
cup_df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting dataframe information

# %% [markdown]
# When looking at the dataframe's `.head()`, you might have noticed that the games are structured chronologically in the dataframe.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
cup_df.iloc[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested to print out the "Home Team Name" and the "Away Team Name",

# %%
cup_df.iloc[5:10][['Home Team Name', 'Away Team Name']]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
is_group3_1950 = (cup_df['Stage'] == 'Group 3') & (cup_df['Year'] == 1950) 

cup_df[is_group3_1950]
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance column for the Group 3 games

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
cup_df['Attendance'][is_group3_1950]
# Out:
# 56    36502.0
# 61     7903.0
# 65    25811.0
# Name: Attendance, dtype: float64

# %% [markdown]
# Throughout the entire history of the world cup, How many Home games were played by the Netherlands?

# %%
is_dutch = (cup_df['Home Team Name'] == 'Netherlands') | (cup_df['Away Team Name'] == 'Netherlands') 
dutch_df = cup_df[is_dutch]
dutch_df.head()
# Out:
#      Year              Datetime              Stage               Stadium  \
# 20   1934  27 May 1934 - 16:30   Preliminary round              San Siro
# 41   1938  05 Jun 1938 - 18:30         First round           Cavee Verte
# 236  1974  15 Jun 1974 - 16:00             Group 3  Niedersachsenstadion
# 244  1974  19 Jun 1974 - 19:30             Group 3      Westfalenstadion
# 252  1974  23 Jun 1974 - 16:00             Group 3      Westfalenstadion
#
#           City  Home Team Name  Home Team Goals  Away Team Goals  \
# 20      Milan      Switzerland                3                2
# 41   Le Havre   Czechoslovakia                3                0
# 236   Hanover          Uruguay                0                2
# 244  Dortmund      Netherlands                0                0
# 252  Dortmund         Bulgaria                1                4
#
#     Away Team Name                        Win conditions  Attendance  \
# 20     Netherlands                                           33000.0
# 41     Netherlands  Czechoslovakia win after extra time      11000.0
# 236    Netherlands                                           55100.0
# 244         Sweden                                           53700.0
# 252    Netherlands                                           53300.0
#
#      Half-time Home Goals  Half-time Away Goals                 Referee  \
# 20                      2                     1       EKLIND Ivan (SWE)
# 41                      0                     0   LECLERCQ Lucien (FRA)
# 236                     0                     1    PALOTAI Karoly (HUN)
# 244                     0                     0  WINSEMANN Werner (CAN)
# 252                     0                     2     BOSKOVIC Tony (AUS)
#
#                  Assistant 1                Assistant 2  RoundID  MatchID  \
# 20       BERANEK Alois (AUT)  BONIVENTO Ferruccio (ITA)      204     1133
# 41            OLIVE D. (FRA)          SDEZ Victor (FRA)      206     1172
# 236      KAZAKOV Pavel (URS)       RAINEA Nicolae (ROU)      262     2098
# 244   TSCHENSCHER Kurt (GER)         THOMAS Clive (WAL)      262     2097
# 252  BIWERSI Ferdinand (GER)    ESCHWEILER Walter (GER)      262     1990
#
#     Home Team Initials Away Team Initials
# 20                 SUI                NED
# 41                 TCH                NED
# 236                URU                NED
# 244                NED                SWE
# 252                BUL                NED

# %% [markdown]
# How many games were played by the Netherlands in total?

# %%
total_dutch_games = len(dutch_df)
total_dutch_games
# Out:
# 54

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 world cup.

# %%
is_2014 = (cup_df['Year'] == 2014)
is_USA = (cup_df['Home Team Name'] == 'USA') | (cup_df['Away Team Name'] == 'USA')

print(len(cup_df[is_2014 & is_USA]))
# Out:
# 5

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 world cup.

# %% [markdown]
# Hint 1: as a first step, create a new data set that only contain games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
is_1986  = (cup_df['Year'] == 1986)
cup86_df = cup_df[is_1986]

cup86_df.head()
print(cup86_df['Home Team Name'].unique())

print(cup86_df['Away Team Name'].unique())

print(len(cup86_df['Home Team Name'].unique()))
# Out:
# ['Bulgaria' 'Canada' 'Spain' 'Soviet Union' 'Argentina' 'Morocco'
#  'Algeria' 'Belgium' 'Portugal' 'Paraguay' 'Scotland' 'Uruguay' 'Italy'
#  'France' 'Korea Republic' 'Hungary' 'Brazil' 'England' 'Northern Ireland'
#  'Mexico' 'Poland' 'Iraq' 'Denmark' 'Germany FR']
# ['Italy' 'France' 'Brazil' 'Hungary' 'Korea Republic' 'Poland'
#  'Northern Ireland' 'Mexico' 'England' 'Iraq' 'Denmark' 'Germany FR'
#  'Argentina' 'Soviet Union' 'Bulgaria' 'Canada' 'Algeria' 'Morocco'
#  'Spain' 'Paraguay' 'Portugal' 'Belgium' 'Uruguay' 'Scotland']
# 24

# %% [markdown]
# In the world cup history, how matches had more than 5 goals in total?

# %%
goals5_df = cup_df.loc[(cup_df['Home Team Goals'] + cup_df['Away Team Goals']) > 5 ]
goals5_df.head()
# Out:
#     Year              Datetime              Stage             Stadium  \
# 10  1930  19 Jul 1930 - 15:00             Group 1  Estadio Centenario
# 15  1930  26 Jul 1930 - 14:45         Semi-finals  Estadio Centenario
# 16  1930  27 Jul 1930 - 14:45         Semi-finals  Estadio Centenario
# 17  1930  30 Jul 1930 - 14:15               Final  Estadio Centenario
# 19  1934  27 May 1934 - 16:30   Preliminary round   Giorgio Ascarelli
#
#            City Home Team Name  Home Team Goals  Away Team Goals  \
# 10  Montevideo       Argentina                6                3
# 15  Montevideo       Argentina                6                1
# 16  Montevideo         Uruguay                6                1
# 17  Montevideo         Uruguay                4                2
# 19      Naples         Hungary                4                2
#
#    Away Team Name Win conditions  Attendance  Half-time Home Goals  \
# 10         Mexico                    42100.0                     3
# 15            USA                    72886.0                     1
# 16     Yugoslavia                    79867.0                     3
# 17      Argentina                    68346.0                     1
# 19          Egypt                     9000.0                     2
#
#     Half-time Away Goals                   Referee             Assistant 1  \
# 10                     1      SAUCEDO Ulises (BOL)  ALONSO Gualberto (URU)
# 15                     0       LANGENUS Jean (BEL)    VALLEJO Gaspar (MEX)
# 16                     1       REGO Gilberto (BRA)    SAUCEDO Ulises (BOL)
# 17                     2       LANGENUS Jean (BEL)    SAUCEDO Ulises (BOL)
# 19                     2  BARLASSINA Rinaldo (ITA)  DATTILO Generoso (ITA)
#
#                    Assistant 2  RoundID  MatchID Home Team Initials  \
# 10  RADULESCU Constantin (ROU)      201     1086                ARG
# 15       WARNKEN Alberto (CHI)      202     1088                ARG
# 16         BALWAY Thomas (FRA)      202     1101                URU
# 17       CRISTOPHE Henry (BEL)      405     1087                URU
# 19          SASSI Otello (ITA)      204     1119                HUN
#
#    Away Team Initials
# 10                MEX
# 15                USA
# 16                YUG
# 17                ARG
# 19                EGY

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column "Half-time Goals".

# %%
test_df = cup_df.copy()
cup_df['Half-time Goals'] = (cup_df['Half-time Home Goals'] + cup_df['Half-time Away Goals'])
cup_df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win condit
# 173     Old Trafford Stadium     Manchester         Portugal                3
# 174               Villa Park     Birmingham        Argentina                2
# 175        Roker Park Ground     Sunderland            Italy                2
# 176               White City         London          Uruguay                2
# 177             Hillsborough      Sheffield            Spain                2
# 178            Goodison Park      Liverpool          Hungary                3
# 179            Ayresome Park  Middlesbrough            Korea                1
# 180     Old Trafford Stadium     Manchester         Portugal                3
# 181               Villa Park     Birmingham       Germany FR                0
# 182        Roker Park Ground     Sunderland     Soviet Union                1
# 183          Wembley Stadium         London          England                2
# 184          Wembley Stadium         London          Uruguay                0
# 185             Hillsborough      Sheffield        Argentina                2
# 186            Goodison Park      Liverpool         Portugal                3
# 187            Ayresome Park  Middlesbrough            Korea                1
# 188          Wembley Stadium         London          England                2
# 189     Old Trafford Stadium     Manchester          Hungary                3
# 190               Villa Park     Birmingham       Germany FR                2
# 191        Roker Park Ground     Sunderland     Soviet Union                2
# 192          Wembley Stadium         London          England                1
# 193             Hillsborough      Sheffield       Germany FR                4
# 194        Roker Park Ground     Sunderland     Soviet Union                2
# 195            Goodison Park      Liverpool         Portugal                5
# 196            Goodison Park      Liverpool       Germany FR                2
# 197          Wembley Stadium         London          England                2
# 198          Wembley Stadium         London         Portugal                2
# 199          Wembley Stadium         London          England                4
#
#      Away Team Goals Away Team Name                 Win conditions  \
# 0                  1         Mexico
# 1                  0        Belgium
# 2                  1         Brazil
# 3                  1           Peru
# 4                  0         France
# 5                  0         Mexico
# 6                  0        Bolivia
# 7                  0       Paraguay
# 8                  0           Peru
# 9                  0         France
# 10                 3         Mexico
# 11                 0        Bolivia
# 12                 0        Belgium
# 13                 0        Romania
# 14                 1          Chile
# 15                 1            USA
# 16                 1     Yugoslavia
# 17                 2      Argentina
# 18                 2         France  Austria win after extra time
# 19                 2          Egypt
# 20                 2    Netherlands
# 21                 2      Argentina
# 22                 2        Belgium
# 23                 1         Brazil
# 24                 1            USA
# 25                 1        Romania
# 26                 2    Switzerland
# 27                 1         Sweden
# 28                 1          Spain
# 29                 1        Hungary
# ..               ...            ...                            ...
# 170                0       Bulgaria
# 171                0          Korea
# 172                1         Mexico
# 173                1        Hungary
# 174                1          Spain
# 175                0          Chile
# 176                1         France
# 177                1    Switzerland
# 178                1         Brazil
# 179                1          Chile
# 180                0       Bulgaria
# 181                0      Argentina
# 182                0          Italy
# 183                0         Mexico
# 184                0         Mexico
# 185                0    Switzerland
# 186                1         Brazil
# 187                0          Italy
# 188                0         France
# 189                1       Bulgaria
# 190                1          Spain
# 191                1          Chile
# 192                0      Argentina
# 193                0        Uruguay
# 194                1        Hungary
# 195                3          Korea
# 196                1   Soviet Union
# 197                1       Portugal
# 198                1   Soviet Union
# 199                2     Germany FR  England win after extra time
#
#           ...        Half-time Home Goals  Half-time Away Goals  \
# 0         ...                           3                     0
# 1         ...                           2                     0
# 2         ...                           2                     0
# 3         ...                           1                     0
# 4         ...                           0                     0
# 5         ...                           1                     0
# 6         ...                           0                     0
# 7         ...                           2                     0
# 8         ...                           0                     0
# 9         ...                           0                     0
# 10        ...                           3                     1
# 11        ...                           1                     0
# 12        ...                           1                     0
# 13        ...                           4                     0
# 14        ...                           2                     1
# 15        ...                           1                     0
# 16        ...                           3                     1
# 17        ...                           1                     2
# 18        ...                           0                     0
# 19        ...                           2                     2
# 20        ...                           2                     1
# 21        ...                           1                     1
# 22        ...                           1                     2
# 23        ...                           3                     0
# 24        ...                           3                     0
# 25        ...                           0                     1
# 26        ...                           1                     1
# 27        ...                           0                     0
# 28        ...                           0                     0
# 29        ...                           1                     0
# ..        ...                         ...                   ...
# 170       ...                           1                     0
# 171       ...                           2                     0
# 172       ...                           0                     0
# 173       ...                           1                     0
# 174       ...                           0                     0
# 175       ...                           1                     0
# 176       ...                           2                     1
# 177       ...                           0                     1
# 178       ...                           1                     1
# 179       ...                           0                     1
# 180       ...                           2                     0
# 181       ...                           0                     0
# 182       ...                           0                     0
# 183       ...                           1                     0
# 184       ...                           0                     0
# 185       ...                           0                     0
# 186       ...                           2                     0
# 187       ...                           1                     0
# 188       ...                           1                     0
# 189       ...                           2                     1
# 190       ...                           1                     1
# 191       ...                           1                     1
# 192       ...                           0                     0
# 193       ...                           1                     0
# 194       ...                           1                     0
# 195       ...                           2                     3
# 196       ...                           1                     0
# 197       ...                           1                     0
# 198       ...                           1                     1
# 199       ...                           0                     0
#
#                              Referee                      Assistant 1  \
# 0             LOMBARDI Domingo (URU)            CRISTOPHE Henry (BEL)
# 1                  MACIAS Jose (ARG)         MATEUCCI Francisco (URU)
# 2                TEJADA Anibal (URU)          VALLARINO Ricardo (URU)
# 3              WARNKEN Alberto (CHI)              LANGENUS Jean (BEL)
# 4                REGO Gilberto (BRA)             SAUCEDO Ulises (BOL)
# 5              CRISTOPHE Henry (BEL)          APHESTEGUY Martin (URU)
# 6           MATEUCCI Francisco (URU)           LOMBARDI Domingo (URU)
# 7                  MACIAS Jose (ARG)          APHESTEGUY Martin (URU)
# 8                LANGENUS Jean (BEL)              BALWAY Thomas (FRA)
# 9                TEJADA Anibal (URU)           LOMBARDI Domingo (URU)
# 10              SAUCEDO Ulises (BOL)           ALONSO Gualberto (URU)
# 11               BALWAY Thomas (FRA)         MATEUCCI Francisco (URU)
# 12           VALLARINO Ricardo (URU)                MACIAS Jose (ARG)
# 13               REGO Gilberto (BRA)            WARNKEN Alberto (CHI)
# 14               LANGENUS Jean (BEL)            CRISTOPHE Henry (BEL)
# 15               LANGENUS Jean (BEL)             VALLEJO Gaspar (MEX)
# 16               REGO Gilberto (BRA)             SAUCEDO Ulises (BOL)
# 17               LANGENUS Jean (BEL)             SAUCEDO Ulises (BOL)
# 18        VAN MOORSEL Johannes (NED)            CAIRONI Camillo (ITA)
# 19          BARLASSINA Rinaldo (ITA)           DATTILO Generoso (ITA)
# 20                 EKLIND Ivan (SWE)              BERANEK Alois (AUT)
# 21                 BRAUN Eugen (AUT)             CARRARO Albino (ITA)
# 22            MATTEA Francesco (ITA)       MELANDRI Ermenegildo (ITA)
# 23               BIRLEM Alfred (GER)           CARMINATI Ettore (ITA)
# 24                 MERCET Rene (SUI)             ESCARTIN Pedro (ESP)
# 25               LANGENUS Jean (BEL)            SCARPI Giuseppe (ITA)
# 26               BERANEK Alois (AUT)            MOHAMED Youssuf (EGY)
# 27          BARLASSINA Rinaldo (ITA)                MERCET Rene (SUI)
# 28                 BAERT Louis (BEL)            ZENISEK Bohumil (TCH)
# 29            MATTEA Francesco (ITA)             ESCARTIN Pedro (ESP)
# ..                               ...                              ...
# 170           TSCHENSCHER Kurt (GER)              McCABE George (ENG)
# 171           GARDEAZABAL Juan (ESP)         KANDIL Aly Hussein (EGY)
# 172         ASHKENAZI Menachem (ISR)   FERNANDES CAMPOS Joaquim (POR)
# 173              CALLAGHAN Leo (WAL)               HOWLEY Kevin (ENG)
# 174         RUMENTCHEV Dimitar (BUL)  YAMASAKI MALDONADO Arturo (MEX)
# 175           DIENST Gottfried (SUI)                 FINNEY Jim (ENG)
# 176                GALBA Karol (TCH)              CALLAGHAN Leo (WAL)
# 177            BAKHRAMOV Tofik (URS)               ZSOLT Istvan (HUN)
# 178            DAGNALL Kenneth (ENG)               HOWLEY Kevin (ENG)
# 179         KANDIL Aly Hussein (EGY)           CRAWFORD William (SCO)
# 180         CODESAL Jose Maria (URU)         GOICOECHEA Roberto (ARG)
# 181         ZECEVIC Konstantin (YUG)   FERNANDES CAMPOS Joaquim (POR)
# 182           KREITLEIN Rudolf (GER)           CRAWFORD William (SCO)
# 183          LO BELLO Concetto (ITA)             CHOI Duk Ryong (PRK)
# 184              LOEOEW Bertil (SWE)             VICUNA Claudio (CHI)
# 185   FERNANDES CAMPOS Joaquim (POR)               ZSOLT Istvan (HUN)
# 186              McCABE George (ENG)              CALLAGHAN Leo (WAL)
# 187            SCHWINTE Pierre (FRA)                 ADAIR John (NIR)
# 188  YAMASAKI MALDONADO Arturo (MEX)                GALBA Karol (TCH)
# 189         GOICOECHEA Roberto (ARG)           GARDEAZABAL Juan (ESP)
# 190            MARQUES Armando (BRA)             VICUNA Claudio (CHI)
# 191                 ADAIR John (NIR)            SCHWINTE Pierre (FRA)
# 192           KREITLEIN Rudolf (GER)           DIENST Gottfried (SUI)
# 193                 FINNEY Jim (ENG)         KANDIL Aly Hussein (EGY)
# 194           GARDEAZABAL Juan (ESP)         CODESAL Jose Maria (URU)
# 195         ASHKENAZI Menachem (ISR)                GALBA Karol (TCH)
# 196          LO BELLO Concetto (ITA)         CODESAL Jose Maria (URU)
# 197            SCHWINTE Pierre (FRA)  YAMASAKI MALDONADO Arturo (MEX)
# 198            DAGNALL Kenneth (ENG)               HOWLEY Kevin (ENG)
# 199           DIENST Gottfried (SUI)            BAKHRAMOV Tofik (URS)
#
#                          Assistant 2 RoundID  MatchID  Home Team Initials  \
# 0                REGO Gilberto (BRA)     201     1096                 FRA
# 1              WARNKEN Alberto (CHI)     201     1090                 USA
# 2                BALWAY Thomas (FRA)     201     1093                 YUG
# 3           MATEUCCI Francisco (URU)     201     1098                 ROU
# 4         RADULESCU Constantin (ROU)     201     1085                 ARG
# 5                LANGENUS Jean (BEL)     201     1095                 CHI
# 6              WARNKEN Alberto (CHI)     201     1092                 YUG
# 7                TEJADA Anibal (URU)     201     1097                 USA
# 8              CRISTOPHE Henry (BEL)     201     1099                 URU
# 9                REGO Gilberto (BRA)     201     1094                 CHI
# 10        RADULESCU Constantin (ROU)     201     1086                 ARG
# 11              VALLEJO Gaspar (MEX)     201     1091                 BRA
# 12            LOMBARDI Domingo (URU)     201     1089                 PAR
# 13              SAUCEDO Ulises (BOL)     201     1100                 URU
# 14              SAUCEDO Ulises (BOL)     201     1084                 ARG
# 15             WARNKEN Alberto (CHI)     202     1088                 ARG
# 16               BALWAY Thomas (FRA)     202     1101                 URU
# 17             CRISTOPHE Henry (BEL)     405     1087                 URU
# 18                 BAERT Louis (BEL)     204     1104                 AUT
# 19                SASSI Otello (ITA)     204     1119                 HUN
# 20         BONIVENTO Ferruccio (ITA)     204     1133                 SUI
# 21           TURBIANI Giuseppe (ITA)     204     1102                 SWE
# 22               BAERT Jacques (FRA)     204     1108                 GER
# 23            IVANCSICS Mihaly (HUN)     204     1111                 ESP
# 24             ZENISEK Bohumil (TCH)     204     1135                 ITA
# 25           SCORZONI Raffaele (ITA)     204     1141                 TCH
# 26               BAERT Jacques (FRA)     418     1143                 TCH
# 27        VAN MOORSEL Johannes (NED)     418     1129                 GER
# 28            IVANCSICS Mihaly (HUN)     418     1122                 ITA
# 29               BIRLEM Alfred (GER)     418     1106                 AUT
# ..                               ...     ...      ...                 ...
# 170                TAYLOR John (ENG)     238     1596                 BRA
# 171           DIENST Gottfried (SUI)     238     1710                 URS
# 172                GALBA Karol (TCH)     238     1650                 FRA
# 173           CLEMENTS William (ENG)     238     1675                 POR
# 174         ZECEVIC Konstantin (YUG)     238     1578                 ARG
# 175           KREITLEIN Rudolf (GER)     238     1608                 ITA
# 176            MARQUES Armando (BRA)     238     1653                 URU
# 177              PHILLIPS Hugh (SCO)     238     1641                 ESP
# 178  YAMASAKI MALDONADO Arturo (MEX)     238     1597                 HUN
# 179                 FINNEY Jim (ENG)     238     1609                 PRK
# 180           TSCHENSCHER Kurt (GER)     238     1602                 POR
# 181              LOEOEW Bertil (SWE)     238     1579                 FRG
# 182         KANDIL Aly Hussein (EGY)     238     1682                 URS
# 183         ASHKENAZI Menachem (ISR)     238     1634                 ENG
# 184          LO BELLO Concetto (ITA)     238     1689                 URU
# 185            BAKHRAMOV Tofik (URS)     238     1582                 ARG
# 186            DAGNALL Kenneth (ENG)     238     1598                 POR
# 187                TAYLOR John (ENG)     238     1679                 PRK
# 188         RUMENTCHEV Dimitar (BUL)     238     1632                 ENG
# 189         CODESAL Jose Maria (URU)     238     1599                 HUN
# 190             CHOI Duk Ryong (PRK)     238     1637                 FRG
# 191           CLEMENTS William (ENG)     238     1610                 URS
# 192               ZSOLT Istvan (HUN)     239     1577                 ENG
# 193              PHILLIPS Hugh (SCO)     239     1660                 FRG
# 194   FERNANDES CAMPOS Joaquim (POR)     239     1676                 URS
# 195            SCHWINTE Pierre (FRA)     239     1702                 POR
# 196           GARDEAZABAL Juan (ESP)     536     1659                 FRG
# 197         ZECEVIC Konstantin (YUG)     536     1635                 ENG
# 198         KANDIL Aly Hussein (EGY)    3479     1709                 POR
# 199                GALBA Karol (TCH)    3478     1633                 ENG
#
#     Away Team Initials Half-time Goals
# 0                  MEX               3
# 1                  BEL               2
# 2                  BRA               2
# 3                  PER               1
# 4                  FRA               0
# 5                  MEX               1
# 6                  BOL               0
# 7                  PAR               2
# 8                  PER               0
# 9                  FRA               0
# 10                 MEX               4
# 11                 BOL               1
# 12                 BEL               1
# 13                 ROU               4
# 14                 CHI               3
# 15                 USA               1
# 16                 YUG               4
# 17                 ARG               3
# 18                 FRA               0
# 19                 EGY               4
# 20                 NED               3
# 21                 ARG               2
# 22                 BEL               3
# 23                 BRA               3
# 24                 USA               3
# 25                 ROU               1
# 26                 SUI               2
# 27                 SWE               0
# 28                 ESP               0
# 29                 HUN               1
# ..                 ...             ...
# 170                BUL               1
# 171                PRK               2
# 172                MEX               0
# 173                HUN               1
# 174                ESP               0
# 175                CHI               1
# 176                FRA               3
# 177                SUI               1
# 178                BRA               2
# 179                CHI               1
# 180                BUL               2
# 181                ARG               0
# 182                ITA               0
# 183                MEX               1
# 184                MEX               0
# 185                SUI               0
# 186                BRA               2
# 187                ITA               1
# 188                FRA               1
# 189                BUL               3
# 190                ESP               2
# 191                CHI               2
# 192                ARG               0
# 193                URU               1
# 194                HUN               1
# 195                PRK               5
# 196                URS               1
# 197                POR               1
# 198                URS               2
# 199                FRG               0
#
# [200 rows x 21 columns]

# %%
# Find all the rows with "Korea" and change the Team initials to 'NSK' 
# Do each, Home and Away, separately so we don't overwrite the opposing team's initials by mistake.
korea_df.loc[korea_df["Home Team Name"].str.contains('Korea'), "Home Team Initials" ] = 'NSK'
korea_df.loc[korea_df["Away Team Name"].str.contains('Korea'), "Away Team Initials" ] = 'NSK'

korea_df.iloc[178:188]
# Out:
#      Year              Datetime    Stage               Stadium  \
# 178  1966  15 Jul 1966 - 19:30   Group 3         Goodison Park
# 179  1966  15 Jul 1966 - 19:30   Group 4         Ayresome Park
# 180  1966  16 Jul 1966 - 15:00   Group 3  Old Trafford Stadium
# 181  1966  16 Jul 1966 - 15:00   Group 2            Villa Park
# 182  1966  16 Jul 1966 - 15:00   Group 4     Roker Park Ground
# 183  1966  16 Jul 1966 - 19:30   Group 1       Wembley Stadium
# 184  1966  19 Jul 1966 - 16:30   Group 1       Wembley Stadium
# 185  1966  19 Jul 1966 - 19:30   Group 2          Hillsborough
# 186  1966  19 Jul 1966 - 19:30   Group 3         Goodison Park
# 187  1966  19 Jul 1966 - 19:30   Group 4         Ayresome Park
#
#                City Home Team Name  Home Team Goals  Away Team Goals  \
# 178      Liverpool         Hungary                3                1
# 179  Middlesbrough           Korea                1                1
# 180     Manchester        Portugal                3                0
# 181     Birmingham      Germany FR                0                0
# 182     Sunderland    Soviet Union                1                0
# 183         London         England                2                0
# 184         London         Uruguay                0                0
# 185      Sheffield       Argentina                2                0
# 186      Liverpool        Portugal                3                1
# 187  Middlesbrough           Korea                1                0
#
#     Away Team Name Win conditions       ...        Half-time Home Goals  \
# 178         Brazil                      ...                           1
# 179          Chile                      ...                           0
# 180       Bulgaria                      ...                           2
# 181      Argentina                      ...                           0
# 182          Italy                      ...                           0
# 183         Mexico                      ...                           1
# 184         Mexico                      ...                           0
# 185    Switzerland                      ...                           0
# 186         Brazil                      ...                           2
# 187          Italy                      ...                           1
#
#      Half-time Away Goals                         Referee  \
# 178                     1           DAGNALL Kenneth (ENG)
# 179                     1        KANDIL Aly Hussein (EGY)
# 180                     0        CODESAL Jose Maria (URU)
# 181                     0        ZECEVIC Konstantin (YUG)
# 182                     0          KREITLEIN Rudolf (GER)
# 183                     0         LO BELLO Concetto (ITA)
# 184                     0             LOEOEW Bertil (SWE)
# 185                     0  FERNANDES CAMPOS Joaquim (POR)
# 186                     0             McCABE George (ENG)
# 187                     0           SCHWINTE Pierre (FRA)
#
#                         Assistant 1                      Assistant 2 RoundID  \
# 178              HOWLEY Kevin (ENG)  YAMASAKI MALDONADO Arturo (MEX)     238
# 179          CRAWFORD William (SCO)                 FINNEY Jim (ENG)     238
# 180        GOICOECHEA Roberto (ARG)           TSCHENSCHER Kurt (GER)     238
# 181  FERNANDES CAMPOS Joaquim (POR)              LOEOEW Bertil (SWE)     238
# 182          CRAWFORD William (SCO)         KANDIL Aly Hussein (EGY)     238
# 183            CHOI Duk Ryong (PRK)         ASHKENAZI Menachem (ISR)     238
# 184            VICUNA Claudio (CHI)          LO BELLO Concetto (ITA)     238
# 185              ZSOLT Istvan (HUN)            BAKHRAMOV Tofik (URS)     238
# 186             CALLAGHAN Leo (WAL)            DAGNALL Kenneth (ENG)     238
# 187                ADAIR John (NIR)                TAYLOR John (ENG)     238
#
#      MatchID  Home Team Initials Away Team Initials Half-time Goals
# 178     1597                 HUN                BRA               2
# 179     1609                 NSK                CHI               1
# 180     1602                 POR                BUL               2
# 181     1579                 FRG                ARG               0
# 182     1682                 URS                ITA               0
# 183     1634                 ENG                MEX               1
# 184     1689                 URU                MEX               0
# 185     1582                 ARG                SUI               0
# 186     1598                 POR                BRA               2
# 187     1679                 NSK                ITA               1
#
# [10 rows x 21 columns]

# %% [markdown]
# Make sure to verify your answer!

# %%
korea_df.iloc[187]
# Out:
# Year                                     1966
# Datetime                 19 Jul 1966 - 19:30
# Stage                                 Group 4
# Stadium                         Ayresome Park
# City                           Middlesbrough
# Home Team Name                          Korea
# Home Team Goals                             1
# Away Team Goals                             0
# Away Team Name                          Italy
# Win conditions
# Attendance                              17829
# Half-time Home Goals                        1
# Half-time Away Goals                        0
# Referee                 SCHWINTE Pierre (FRA)
# Assistant 1                  ADAIR John (NIR)
# Assistant 2                 TAYLOR John (ENG)
# RoundID                                   238
# MatchID                                  1679
# Home Team Initials                        PRK
# Away Team Initials                        ITA
# Half-time Goals                             1
# Name: 187, dtype: object

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to access data within Pandas!
